# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('SMSSpamCollection.csv', sep='\t',names=['Label','Text'])
data
# Out:
#      Label                                               Text
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
data
# Out:
#      Label                                               Text
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %% [raw]
# Data Cleaning Process
# -> remove pancuatation words
# -> Remove stop words (repeatitive words - was,the,i,any,for)
# -> Perform Stmming (playing -> play , acting -> act, friends -> friend, likes -> like)

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
sentence = "Hello friends! How are you?"

# %%
sentence
# Out:
# 'Hello friends! How are you?'

# %%
from nltk import word_tokenize
from nltk.corpus import stopwords

# %%
print(word_tokenize(sentence))
# Out:
# ['Hello', 'friends', '!', 'How', 'are', 'you', '?']

# %%
from nltk.corpus import stopwords

# %%
swords = stopwords.words('english')

# %%
swords
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
clean = [word for word in word_tokenize(sentence) if word not in swords]

# %%
clean
# Out:
# ['Hello', 'friends', '!', 'How', '?']

# %%
from nltk.stem import PorterStemmer
ps =PorterStemmer()
clean = [ps.stem(word) for word in clean]
clean
# Out:
# ['hello', 'friend', '!', 'how', '?']

# %%
def cleanText(sent):
    tokens = word_tokenize(sent)
    clean = [word for word in tokens if word.isdigit() or word.isalpha()]
    clean = [ps.stem(word) for word in clean if word not in swords ]
    return clean

# %%
sent = cleanText('Hello friends! How are you? We\'ll be learning python today' )

# %%
print(sent)
# Out:
# ['hello', 'friend', 'how', 'we', 'learn', 'python', 'today']

# %%
# TF-IDF - Term frequency Inverse Document Frequency
# TF(t) = no. of times term t appears in a document / total no. of terms in the document 
#  Eg term = 'hello' -> term
# document -> row for the term hello 

# IDF(t) = loge total no. of documents / no. of documents with term t in it
# To use TF-IDF method we can convert our data into number format
# W(x,y) = (tf(x,y) * log n ) / df(x) where tf(x,y) = frequency of x in y 
#              df(x) = no. of documents containing x , n = total no. of documents

# %%
#Preprocessing
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(analyzer=cleanText);

# %%
y = data.Label
x = data.Text

# %%
x_new = tfidf.fit_transform(x)

# %%
print(x.shape)
print(x_new.shape) # where 6513 are unique words exists which have been converted into the column
# Out:
# (5572,)
# (5572, 6513)

# %%
print(x_new)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 52578 stored elements and shape (5572, 6513)>
#   Coords	Values
#   (0, 2602)	0.13538587933397997
#   (0, 3234)	0.33773998989051757
#   (0, 4416)	0.23061600566766993
#   (0, 1642)	0.26155637320808295
#   (0, 875)	0.2546627830679494
#   (0, 1226)	0.28532410826254967
#   (0, 3886)	0.18138906844909788
#   (0, 2670)	0.18691623884268135
#   (0, 6366)	0.22641055703609397
#   (0, 3336)	0.28532410826254967
#   (0, 2023)	0.20121094441090445
#   (0, 1224)	0.3224093272932175
#   (0, 1449)	0.28532410826254967
#   (0, 2638)	0.15656739531298178
#   (0, 691)	0.33773998989051757
#   (0, 6193)	0.18656775650261379
#   (1, 4107)	0.2791181079705321
#   (1, 3364)	0.4119413485532704
#   (1, 3204)	0.46727681005422184
#   (1, 6291)	0.4354514107002345
#   (1, 5957)	0.20079570761085996
#   (1, 4132)	0.5514643620986254
#   (2, 2447)	0.11980757112588468
#   (2, 2127)	0.3727440092410635
#   (2, 292)	0.10372163016435682
#   :	:
#   (5568, 2436)	0.46042030134261525
#   (5568, 2156)	0.52827241078615
#   (5569, 5246)	0.3206133417588562
#   (5569, 5507)	0.5295640248979575
#   (5569, 3811)	0.5021550803083344
#   (5569, 4373)	0.6038288697475673
#   (5570, 2447)	0.18817482474548594
#   (5570, 2962)	0.10418981861112665
#   (5570, 6222)	0.21635843240085437
#   (5570, 3437)	0.18568020399563048
#   (5570, 5702)	0.21982076321027347
#   (5570, 3966)	0.24703972051375683
#   (5570, 6050)	0.24778016134287534
#   (5570, 5268)	0.24151943425367756
#   (5570, 1251)	0.24151943425367756
#   (5570, 2085)	0.28699735270806603
#   (5570, 2536)	0.3237737103823975
#   (5570, 2713)	0.24559457421299682
#   (5570, 3081)	0.30988011869012017
#   (5570, 557)	0.3509259578444351
#   (5570, 1072)	0.3440206779047631
#   (5571, 3898)	0.4524722511779951
#   (5571, 3120)	0.343886755927807
#   (5571, 5908)	0.5012687927120153
#   (5571, 4844)	0.652487822464454

# %%
y.value_counts()
# Out:
# Label
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
#cross validation testing
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x_new,y,random_state=0,test_size=0.25)

# %%
X_train.shape
# Out:
# (4179, 6513)

# %%
X_test.shape
# Out:
# (1393, 6513)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb = GaussianNB()
nb.fit(X_train.toarray(),y_train)
# Out:
# GaussianNB()

# %%
y_pred = nb.predict(X_test.toarray())

# %%
y_pred
# Out:
# array(['ham', 'spam', 'ham', ..., 'spam', 'ham', 'ham'], dtype='<U4')

# %%
y_test.value_counts()
# Out:
# Label
# ham     1208
# spam     185
# Name: count, dtype: int64

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# %%
con = ConfusionMatrixDisplay.from_predictions(y_test,y_pred,cmap='cividis',xticks_rotation=60);

# %%
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(y_test,y_pred)
mat
# Out:
# array([[1051,  157],
#        [  20,  165]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.98      0.87      0.92      1208
#         spam       0.51      0.89      0.65       185
#
#     accuracy                           0.87      1393
#    macro avg       0.75      0.88      0.79      1393
# weighted avg       0.92      0.87      0.89      1393

# %%
from sklearn.ensemble import RandomForestClassifier #ensemble algo

# %%
rf = RandomForestClassifier(random_state=0)
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
y_pred2 = rf.predict(X_test)

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# %%
ConfusionMatrixDisplay.from_predictions(y_test,y_pred2,cmap='magma',xticks_rotation=60);

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.98      1.00      0.99      1208
#         spam       0.99      0.86      0.92       185
#
#     accuracy                           0.98      1393
#    macro avg       0.98      0.93      0.96      1393
# weighted avg       0.98      0.98      0.98      1393

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
log=LogisticRegression()
log.fit(X_train,y_train)
y_pred=log.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.9641062455132807

# %%
from sklearn.model_selection import GridSearchCV

params = {
    'criterion':['gini','entropy'],
    'max_features':['sqrt','log2'],
    'random_state':[0,1,2,3,4],
    'class_weight':['balanced','balanced_subsample']
}

# %%
grid = GridSearchCV(rf,param_grid=params,cv=5,scoring='accuracy',verbose=3)
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV 1/5] END class_weight=balanced, criterion=gini, max_features=sqrt, random_state=0;, score=0.975 total time=   3.6s
# [CV 2/5] END class_weight=balanced, criterion=gini, max_features=sqrt, random_state=0;, score=0.965 total time=   6.0s
# [CV 3/5] END class_weight=balanced, criterion=gini, max_features=sqrt, random_state=0;, score=0.978 total time=   3.5s
# [CV 4/5] END class_weight=balanced, criterion=gini, max_features=sqrt, random_state=0;, score=0.965 total time=   3.2s
# [CV 5/5] END class_weight=balanced, criterion=gini, max_features=sqrt, random_state=0;, score=0.968 total time=   3.3s
# [CV 1/5] END class_weight=balanced, criterion=gini, max_features=sqrt, random_state=1;, score=0.978 total time=   3.2s
# [CV 2/5] END class_weight=balanced, criterion=gini, max_features=sqrt, random_state=1;, score=0.963 total time=   3.2s
# [CV 3/5] END class_weight=balanced, criterion=gini, max_features=sqrt, random_state=1;, score=0.977 total time=   3.2s
# [CV 4/5] END class_weight=balanced, criterion=gini, max_features=sqrt, random_state=1;, score=0.959 total time=   2.8s
# [CV 5/5] END class_weight=balanced, criterion=gini, max_features=sqrt, random_state=1;, score=0.978 total time=   3.3s
# [CV 1/5] END class_weight=balanced, criterion=gini, max_features=sqrt, random_state=2;, score=0.974 total time=   3.6s
# [CV 2/5] END class_weight=balanced, criterion=gini, max_features=sqrt, random_state=2;, score=0.957 total time=   3.9s
# [CV 3/5] END class_weight=balanced, criterion=gini, max_features=sqrt, random_state=2;, score=0.976 total time=   3.5s
# [CV 4/5] END class_weight=balanced, criterion=gini, max_features=sqrt, random_state=2;, score=0.964 total time=   3.1s
# [CV 5/5] END class_weight=balanced, criterion=gini, max_features=sqrt, random_state=2;, score=0.981 total time=   3.5s
# [CV 1/5] END class_weight=balanced, criterion=gini, max_features=sqrt, random_state=3;, score=0.976 total time=   3.4s
# [CV 2/5] END class_weight=balanced, criterion=gini, max_features=sqrt, random_state=3;, score=0.963 total time=   3.4s
# [CV 3/5] END class_weight=balanced, criterion=gini, max_features=sqrt, random_state=3;, score=0.975 total time=   3.1s
# [CV 4/5] END class_weight=balanced, criterion=gini, max_features=sqrt, random_state=3;, score=0.964 total time=   2.8s
# [CV 5/5] END class_weight=balanced, criterion=gini, max_features=sqrt, random_state=3;, score=0.978 total time=   3.2s
# [CV 1/5] END class_weight=balanced, criterion=gini, max_features=sqrt, random_state=4;, score=0.968 total time=   3.4s
# [CV 2/5] END class_weight=balanced, criterion=gini, max_features=sqrt, random_state=4;, score=0.964 total time=   3.1s
# [CV 3/5] END class_weight=balanced, criterion=gini, max_features=sqrt, random_state=4;, score=0.968 total time=   3.1s
# [CV 4/5] END class_weight=balanced, criterion=gini, max_features=sqrt, random_state=4;, score=0.962 total time=   2.9s
# [CV 5/5] END class_weight=balanced, criterion=gini, max_features=sqrt, random_state=4;, score=0.978 total time=   3.1s
# [CV 1/5] END class_weight=balanced, criterion=gini, max_features=log2, random_state
5] END class_weight=balanced, criterion=entropy, max_features=log2, random_state=2;, score=0.957 total time=   3.6s
# [CV 5/5] END class_weight=balanced, criterion=entropy, max_features=log2, random_state=2;, score=0.971 total time=   3.5s
# [CV 1/5] END class_weight=balanced, criterion=entropy, max_features=log2, random_state=3;, score=0.968 total time=   3.7s
# [CV 2/5] END class_weight=balanced, criterion=entropy, max_features=log2, random_state=3;, score=0.965 total time=   3.6s
# [CV 3/5] END class_weight=balanced, criterion=entropy, max_features=log2, random_state=3;, score=0.968 total time=   3.6s
# [CV 4/5] END class_weight=balanced, criterion=entropy, max_features=log2, random_state=3;, score=0.956 total time=   3.5s
# [CV 5/5] END class_weight=balanced, criterion=entropy, max_features=log2, random_state=3;, score=0.972 total time=   3.3s
# [CV 1/5] END class_weight=balanced, criterion=entropy, max_features=log2, random_state=4;, score=0.964 total time=   3.7s
# [CV 2/5] END class_weight=balanced, criterion=entropy, max_features=log2, random_state=4;, score=0.962 total time=   3.5s
# [CV 3/5] END class_weight=balanced, criterion=entropy, max_features=log2, random_state=4;, score=0.967 total time=   3.4s
# [CV 4/5] END class_weight=balanced, criterion=entropy, max_features=log2, random_state=4;, score=0.957 total time=   3.3s
# [CV 5/5] END class_weight=balanced, criterion=entropy, max_features=log2, random_state=4;, score=0.970 total time=   3.2s
# [CV 1/5] END class_weight=balanced_subsample, criterion=gini, max_features=sqrt, random_state=0;, score=0.978 total time=   3.1s
# [CV 2/5] END class_weight=balanced_subsample, criterion=gini, max_features=sqrt, random_state=0;, score=0.970 total time=   3.2s
# [CV 3/5] END class_weight=balanced_subsample, criterion=gini, max_features=sqrt, random_state=0;, score=0.977 total time=   3.4s
# [CV 4/5] END class_weight=balanced_subsample, criterion=gini, max_features=sqrt, random_state=0;, score=0.968 total time=   2.9s
# [CV 5/5] END class_weight=balanced_subsample, criterion=gini, max_features=sqrt, random_state=0;, score=0.970 total time=   3.6s
# [CV 1/5] END class_weight=balanced_subsample, criterion=gini, max_features=sqrt, random_state=1;, score=0.977 total time=   3.5s
# [CV 2/5] END class_weight=balanced_subsample, criterion=gini, max_features=sqrt, random_state=1;, score=0.968 total time=   3.8s
# [CV 3/5] END class_weight=balanced_subsample, criterion=gini, max_features=sqrt, random_state=1;, score=0.977 total time=   3.4s
# [CV 4/5] END class_weight=balanced_subsample, criterion=gini, max_features=sqrt, random_state=1;, score=0.962 total time=   2.9s
# [CV 5/5] END class_weight=balanced_subsample, criterion=gini, max_features=sqrt, random_state=1;, score=0.980 total time=   3.2s
# [CV 1/5] END class_weight=balanced_subsample, criterion=gini, max_features=sqrt, random_state=2;, score=0.972 total time=   3.2s
# [CV 2/5] END class_weight=balanced_subsample, criterion=gini, max_features=sqrt, random_state=2;, score=0.958 total time=   3.2s
# [CV 3/5] END class_weight=balanced_subsample, criterion=gini, max_features=sqrt, random_state=2;, score=0.975 total time=   3.2s
# [CV 4/5] END class_weight=balanced_subsample, criterion=gini, max_features=sqrt, random_state=2;, score=0.961 total time=   2.9s
# [CV 5/5] END class_weight=balanced_subsample, criterion=gini, max_features=sqrt, random_state=2;, score=0.974 total time=   3.2s
# [CV 1/5] END class_weight=balanced_subsample, criterion=gini, max_features=sqrt, random_state=3;, score=0.976 total time=   3.9s
# [CV 2/5] END class_weight=balanced_subsample, criterion=gini, max_features=sqrt, random_state=3;, score=0.962 total time=   3.6s
# [CV 3/5] END class_weight=balanced_subsample, criterion=gini, max_features=sqrt, random_state=3;, score=0.976 total time=   3.3s
# [CV 4/5] END class_weight=balanced_subsample, criterion=gini, max_features=sqrt, random_state=3;, score=0.962 total time=   3.0s
# [CV 5/5] END class_weight=balanced_subsample, criterion=gini, max_features=sqrt, random_state=3;, score=0.978 total time=   3.5s
# [CV 1/5] END class_weight=balanced_subsample, criterion=gini, max_features=sqrt, random_state=4;, score=0.971 total time=   3.2s
# [CV 2/5] END class_weight=balanced_subsample, criterion=gini, max_features=sqrt, random_state=4;, score=0.959 total time=   3.4s
# [CV 3/5] END class_weight=balanced_subsample, criterion=gini, max_features=sqrt, random_state=4;, score=0.963 total time=   3.4s
# [CV 4/5] END class_weight=balanced_subsample, criterion=gini, max_features=sqrt, random_state=4;, score=0.962 total time=   3.1s
# [CV 5/5] END class_weight=balanced_subsample, criterion=gini, max_features=sqrt, random_state=4;, score=0.978 total time=   3.3s
# [CV 1/5] END class_weight=balanced_subsample, criterion=gini, max_features=log2, random_state=0;, score=0.963 total time=   3.6s
# [CV 2/5] END class_weight=balanced_subsample, criterion=gini, max_features=log2, random_state=0;, score=0.958 total time=   3.6s
# [CV 3/5] END class_weight=balanced_subsample, criterion=gini, max_features=log2, random_state=0;, score=0.969 total time=   3.6s
# [CV 4/5] END class_weight=balanced_subsample, criterion=gini, max_features=log2, random_state=0;, score=0.955 total time=   3.3s
# [CV 5/5] END class_weight=balanced_subsample, criterion=gini, max_features=log2, random_state=0;, score=0.970 total time=   3.6s
# [CV 1/5] END class_weight=balanced_subsample, criterion=gini, max_features=log2, random_state=1;, score=0.968 total time=   3.5s
# [CV 2/5] END class_weight=balanced_subsample, criterion=gini, max_features=log2, random_state=1;, score=0.959 total time=   3.5s
# [CV 3/5] END class_weight=balanced_subsample, criterion=gini, max_features=log2, random_state=1;, score=0.969 total time=   3.6s
# [CV 4/5] END class_weight=balanced_subsample, criterion=gini, max_features=log2, random_state=1;, score=0.959 total time=   3.5s
# [CV 5/5] END class_weight=balanced_subsample, criterion=gini, max_features=log2, random_state=1;, score=0.970 total time=   3.7s
# [CV 1/5] END class_weight=balanced_subsample, criterion=gini, max_features=log2, random_state=2;, score=0.964 total time=   3.7s
# [CV 2/5] END class_weight=balanced_subsample, criterion=gini, max_features=log2, random_state=2;, score=0.961 total time=   3.7s
# [CV 3/5] END class_weight=balanced_subsample, criterion=gini, max_features=log2, random_state=2;, score=0.971 total time=   3.6s
# [CV 4/5] END class_weight=balanced_subsample, criterion=gini, max_features=log2, random_state=2;, score=0.953 total time=   3.5s
# [CV 5/5] END class_weight=balanced_subsample, criterion=gini, max_features=log2, random_state=2;, score=0.971 total time=   3.6s
# [CV 1/5] END class_weight=balanced_subsample, criterion=gini, max_features=log2, random_state=3;, score=0.962 total time=   3.5s
# [CV 2/5] END class_weight=balanced_subsample, criterion=gini, max_features=log2, random_state=3;, score=0.962 total time=   3.5s
# [CV 3/5] END class_weight=balanced_subsample, criterion=gini, max_features=log2, random_state=3;, score=0.968 total time=   3.6s
# [CV 4/5] END class_weight=balanced_subsample, criterion=gini, max_features=log2, random_state=3;, score=0.952 total time=   3.4s
# [CV 5/5] END class_weight=balanced_subsample, criterion=gini, max_features=log2, random_state=3;, score=0.969 total time=   3.7s
# [CV 1/5] END class_weight=balanced_subsample, criterion=gini, max_features=log2, random_state=4;, score=0.967 total time=   3.6s
# [CV 2/5] END class_weight=balanced_subsample, criterion=gini, max_features=log2, random_state=4;, score=0.961 total time=   3.5s
# [CV 3/5] END class_weight=balanced_subsample, criterion=gini, max_features=log2, random_state=4;, score=0.962 total time=   3.5s
# [CV 4/5] END class_weight=balanced_subsample, criterion=gini, max_features=log2, random_state=4;, score=0.957 total time=   3.4s
# [CV 5/5] END class_weight=balanced_subsample, criterion=gini, max_features=log2, random_state=4;, score=0.976 total time=   3.8s
# [CV 1/5] END class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, random_state=0;, score=0.977 total time=   3.2s
# [CV 2/5] END class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, random_state=0;, score=0.964 total time=   3.1s
# [CV 3/5] END class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, random_state=0;, score=0.980 total time=   3.3s
# [CV 4/5] END class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, random_state=0;, score=0.964 total time=   2.9s
# [CV 5/5] END class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, random_state=0;, score=0.971 total time=   3.2s
# [CV 1/5] END class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, random_state=1;, score=0.981 total time=   3.0s
# [CV 2/5] END class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, random_state=1;, score=0.964 total time=   2.9s
# [CV 3/5] END class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, random_state=1;, score=0.974 total time=   3.0s
# [CV 4/5] END class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, random_state=1;, score=0.961 total time=   2.7s
# [CV 5/5] END class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, random_state=1;, score=0.977 total time=   3.1s
# [CV 1/5] END class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, random_state=2;, score=0.970 total time=   3.1s
# [CV 2/5] END class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, random_state=2;, score=0.959 total time=   3.1s
# [CV 3/5] END class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, random_state=2;, score=0.971 total time=   3.2s
# [CV 4/5] END class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, random_state=2;, score=0.961 total time=   2.8s
# [CV 5/5] END class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, random_state=2;, score=0.975 total time=   3.1s
# [CV 1/5] END class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, random_state=3;, score=0.974 total time=   3.1s
# [CV 2/5] END class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, random_state=3;, score=0.964 total time=   3.0s
# [CV 3/5] END class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, random_state=3;, score=0.976 total time=   3.2s
# [CV 4/5] END class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, random_state=3;, score=0.959 total time=   2.8s
# [CV 5/5] END class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, random_state=3;, score=0.980 total time=   3.1s
# [CV 1/5] END class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, random_state=4;, score=0.975 total time=   3.1s
# [CV 2/5] END class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, random_state=4;, score=0.959 total time=   3.1s
# [CV 3/5] END class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, random_state=4;, score=0.963 total time=   3.3s
# [CV 4/5] END class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, random_state=4;, score=0.962 total time=   2.7s
# [CV 5/5] END class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, random_state=4;, score=0.978 total time=   3.2s
# [CV 1/5] END class_weight=balanced_subsample, criterion=entropy, max_features=log2, random_state=0;, score=0.968 total time=   3.5s
# [CV 2/5] END class_weight=balanced_subsample, criterion=entropy, max_features=log2, random_state=0;, score=0.961 total time=   3.7s
# [CV 3/5] END class_weight=balanced_subsample, criterion=entropy, max_features=log2, random_state=0;, score=0.965 total time=   3.5s
# [CV 4/5] END class_weight=balanced_subsample, criterion=entropy, max_features=log2, random_state=0;, score=0.956 total time=   3.4s
# [CV 5/5] END class_weight=balanced_subsample, criterion=entropy, max_features=log2, random_state=0;, score=0.970 total time=   3.5s
# [CV 1/5] END class_weight=balanced_subsample, criterion=entropy, max_features=log2, random_state=1;, score=0.970 total time=   3.4s
# [CV 2/5] END class_weight=balanced_subsample, criterion=entropy, max_features=log2, random_state=1;, score=0.964 total time=   3.4s
# [CV 3/5] END class_weight=balanced_subsample, criterion=entropy, max_features=log2, random_state=1;, score=0.968 total time=   3.8s
# [CV 4/5] END class_weight=balanced_subsample, criterion=entropy, max_features=log2, random_state=1;, score=0.955 total time=   3.6s
# [CV 5/5] END class_weight=balanced_subsample, criterion=entropy, max_features=log2, random_state=1;, score=0.970 total time=   3.9s
# [CV 1/5] END class_weight=balanced_subsample, criterion=entropy, max_features=log2, random_state=2;, score=0.959 total time=   3.5s
# [CV 2/5] END class_weight=balanced_subsample, criterion=entropy, max_features=log2, random_state=2;, score=0.958 total time=   3.9s
# [CV 3/5] END class_weight=balanced_subsample, criterion=entropy, max_features=log2, random_state=2;, score=0.968 total time=   3.8s
# [CV 4/5] END class_weight=balanced_subsample, criterion=entropy, max_features=log2, random_state=2;, score=0.956 total time=   3.9s
# [CV 5/5] END class_weight=balanced_subsample, criterion=entropy, max_features=log2, random_state=2;, score=0.971 total time=   3.6s
# [CV 1/5] END class_weight=balanced_subsample, criterion=entropy, max_features=log2, random_state=3;, score=0.971 total time=   3.7s
# [CV 2/5] END class_weight=balanced_subsample, criterion=entropy, max_features=log2, random_state=3;, score=0.963 total time=   3.7s
# [CV 3/5] END class_weight=balanced_subsample, criterion=entropy, max_features=log2, random_state=3;, score=0.967 total time=   3.6s
# [CV 4/5] END class_weight=balanced_subsample, criterion=entropy, max_features=log2, random_state=3;, score=0.956 total time=   3.4s
# [CV 5/5] END class_weight=balanced_subsample, criterion=entropy, max_features=log2, random_state=3;, score=0.972 total time=   3.5s
# [CV 1/5] END class_weight=balanced_subsample, criterion=entropy, max_features=log2, random_state=4;, score=0.961 total time=   4.1s
# [CV 2/5] END class_weight=balanced_subsample, criterion=entropy, max_features=log2, random_state=4;, score=0.961 total time=   3.7s
# [CV 3/5] END class_weight=balanced_subsample, criterion=entropy, max_features=log2, random_state=4;, score=0.963 total time=   3.7s
# [CV 4/5] END class_weight=balanced_subsample, criterion=entropy, max_features=log2, random_state=4;, score=0.956 total time=   3.6s
# [CV 5/5] END class_weight=balanced_subsample, criterion=entropy, max_features=log2, random_state=4;, score=0.972 total time=   4.3s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=0),
#              param_grid={'class_weight': ['balanced', 'balanced_subsample'],
#                          'criterion': ['gini', 'entropy'],
#                          'max_features': ['sqrt', 'log2'],
#                          'random_state': [0, 1, 2, 3, 4]},
#              scoring='accuracy', verbose=3)

# %%
rf = grid.best_estimator_
y_pred = rf.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.9813352476669059
